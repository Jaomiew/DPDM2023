# %% [markdown]
# <a href="https://colab.research.google.com/github/Jaomiew/DPDM2023/blob/main/midterm_dpdm2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Use the latest Thai's general election data here https://docs.google.com/spreadsheets/d/1fROfZuM7150UjGEQksRMkoVxZ4dBYDTR/edit?usp=share_link&ouid=115237908096743617902&rtpof=true&sd=true
#
# (***Thai's general election detail***: Of the 500 members of the House of Representatives to be elected, 400 seats are elected from single-member constituencies by first-past-the-post voting, and 100 party-list seats—filled separately—are voted on in a separate ballot. ELECTED constituency candidate is the constituency candidate who recieved the highest votes, the party list is vote for the party)
#
# to write excutable codes for the following instructions,
#
#
# 1. create a table that shows a list of ELECTED constituency candidate names and their parties. Sort the table by the number of votes they received and showed only top 10 (30 points)
# 2. create a table that shows a list of ELECTED constituency candidate names and their parties. Sort the table by voted they received and showed only 5 worst perform (30 points)
# 3. create a table from the party list vote result that shows the ratio between the vote recieved by the highest party and the second highest party of each constituency area.
#
#  ($\frac{V1}{V2}$ where $V1$ is the number of votes the highest paty received and $V2$ is the number of votes the second highest paty received)
#
# The table should include name of the constituency area, district, province, name of the top party, name of the runner-up party, and $\frac{V1}{V2}$
# (60 points)
#
# Full score 100 points (bonus 20 points)

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive # เชื่อม google drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 1.create a table that shows a list of ELECTED constituency candidate names and their parties. Sort the table by the number of votes they received and showed only top 10 (30 points)
#
# สร้างตารางที่แสดงรายการชื่อผู้สมัครรับเลือกตั้งแบบแบ่งเขตเลือกตั้งและพรรค
# เรียงตารางตามจำนวนโหวตที่ได้รับและแสดงเฉพาะ 10 อันดับแรก (30 คะแนน)

# %% [markdown]
# ## Input Data

# %%
md1_1 = pd.read_csv('/content/drive/MyDrive/DPDM23_DATA/Candidate_Constituency.csv') #ข้อมูลชุดที่1 แสดงรายชื่อผู้สมัครรับเลือกตั้งแบบแบ่งเขตและสังกัดพรรค
md1_1.head()
# Out:
#   mp_app_id             mp_app_name  mp_app_no  mp_app_party_id  \
# 0   ACR_1_1   นางสาวปิยะมาศ บัวแก้ว          1              706
# 1  ACR_1_10  นางสุขสมรวย วันทนียกุล         10              709
# 2  ACR_1_11     นายการันต์ ลุนพันธ์         11              712
# 3  ACR_1_12          นายไสว ผลาวงศ์         12              742
# 4  ACR_1_13        นายสงบ โสภิพันธ์         13              761
#
#                                            image_url
# 0  https://cdn.ectreport.com/images/mp_candidates...
# 1  https://cdn.ectreport.com/images/mp_candidates...
# 2  https://cdn.ectreport.com/images/mp_candidates...
# 3  https://cdn.ectreport.com/images/mp_candidates...
# 4  https://cdn.ectreport.com/images/mp_candidates...

# %%
md1_2 = pd.read_csv('/constituencies_Candidate.csv') #ข้อมูลชุดที่2 แสดงผลโหวตการเลือกตั้งประเภทแบบเขต
md1_2.head()
# Out:
#   cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id
# 0   ACR_1   ACR_1_1            9          459              0.43477       706
# 1   ACR_1  ACR_1_10            1        38275             36.25419       709
# 2   ACR_1  ACR_1_11           13          126              0.11935       712
# 3   ACR_1  ACR_1_12           12          127              0.12029       742
# 4   ACR_1  ACR_1_13           11          212              0.20081       761

# %%
md1_3=pd.read_csv('/result_constituencies_PartyList.csv') #ข้อมูลชุดที่3 แสดงผลโหวตการเลือกตั้งประเภทแบบพรรค
md1_3.head()
# Out:
#   cons_id  party_id  party_list_vote  party_list_vote_percent
# 0   ACR_1       701             4550                  4.30977
# 1   ACR_1       702              185                  0.17523
# 2   ACR_1       703               67                  0.06346
# 3   ACR_1       705            33576                 31.80328
# 4   ACR_1       706              132                  0.12503

# %%
md1_4=pd.read_csv('/info_party_overview.csv') #ข้อมูลชุดที่3 แสดงผลโหวตการเลือกตั้งประเภทแบบพรรค
md1_4.head()
# Out:
#     id  party_no           name  abbr    color  \
# 0  701      26.0   ประชาธิปัตย์  ปชป.  #06aff3
# 1  702      63.0     ประชากรไทย  ปชท.  #0f41ce
# 2  703      60.0   ความหวังใหม่  ควม.  #e6b750
# 3  705      29.0       เพื่อไทย   พท.  #da3731
# 4  706      14.0  ชาติพัฒนากล้า  ชพก.  #233e8a
#
#                                             logo_url
# 0  https://cdn.ectreport.com/images/logos/ประชาธิ...
# 1  https://cdn.ectreport.com/images/logos/ประชากร...
# 2  https://cdn.ectreport.com/images/logos/ความหวั...
# 3  https://cdn.ectreport.com/images/logos/เพื่อไท...
# 4  https://cdn.ectreport.com/images/logos/ชาติพัฒ...

# %%
newmd1_4 = md1_4[['id','name']] #ข้อมูลทีแสดงรายชื่อพรรค
newmd1_4
# Out:
#      id           name
# 0   701   ประชาธิปัตย์
# 1   702     ประชากรไทย
# 2   703   ความหวังใหม่
# 3   705       เพื่อไทย
# 4   706  ชาติพัฒนากล้า
# ..  ...            ...
# 65  780    ไทยก้าวหน้า
# 66  781           พลัง
# 67  783  ชาติรุ่งเรือง
# 68  784       รวมใจไทย
# 69  786        เปลี่ยน
#
# [70 rows x 2 columns]

# %% [markdown]
# ## เช็ค missing value ทั้ง 4 ตาราง

# %%
md1_1.isnull().any() # ไม่มีค่า missing value
# Out:
# mp_app_id          False
# mp_app_name        False
# mp_app_no          False
# mp_app_party_id    False
# image_url          False
# dtype: bool

# %%
md1_2.isnull().any() # ไม่มีค่า missing value
# Out:
# cons_id                False
# mp_app_id              False
# mp_app_rank            False
# mp_app_vote            False
# mp_app_vote_percent    False
# party_id               False
# dtype: bool

# %%
md1_3.isnull().any() # ไม่มีค่า missing value
# Out:
# cons_id                    False
# party_id                   False
# party_list_vote            False
# party_list_vote_percent    False
# dtype: bool

# %%
md1_4.isnull().any() # ไม่มีค่า missing value
# Out:
# id          False
# party_no     True
# name        False
# abbr        False
# color       False
# logo_url    False
# dtype: bool

# %% [markdown]
# ## รวมตาราง

# %%
merged_df = pd.merge(md1_1, md1_2) #ทำการรวมตารางmd1_1 และ md1_2 เข้าด้วยกัน
merged_df
# Out:
#      mp_app_id             mp_app_name  mp_app_no  mp_app_party_id  \
# 0      ACR_1_1   นางสาวปิยะมาศ บัวแก้ว          1              706
# 1     ACR_1_10  นางสุขสมรวย วันทนียกุล         10              709
# 2     ACR_1_11     นายการันต์ ลุนพันธ์         11              712
# 3     ACR_1_12          นายไสว ผลาวงศ์         12              742
# 4     ACR_1_13        นายสงบ โสภิพันธ์         13              761
# ...        ...                     ...        ...              ...
# 4776   YST_3_5       นายธนพัฒน์ ศรีชนะ          5              709
# 4777   YST_3_6        นายพิทยา พาลุสุข          6              763
# 4778   YST_3_7      นายศรายุทธ สุดสวาท          7              712
# 4779   YST_3_8    นางสาวสุนันทา สีชมภู          8              769
# 4780   YST_3_9        นายณัฐพล ศรีอุบล          9              726
#
#                                               image_url cons_id  mp_app_rank  \
# 0     https://cdn.ectreport.com/images/mp_candidates...   ACR_1            9
# ...

# %%
merged_df = pd.merge(merged_df, md1_3) #รวมตารางmerged_df และ md1_3 เข้าด้วยกัน
merged_df
# Out:
#      mp_app_id             mp_app_name  mp_app_no  mp_app_party_id  \
# 0      ACR_1_1   นางสาวปิยะมาศ บัวแก้ว          1              706
# 1     ACR_1_10  นางสุขสมรวย วันทนียกุล         10              709
# 2     ACR_1_11     นายการันต์ ลุนพันธ์         11              712
# 3     ACR_1_12          นายไสว ผลาวงศ์         12              742
# 4     ACR_1_13        นายสงบ โสภิพันธ์         13              761
# ...        ...                     ...        ...              ...
# 4772   YST_3_5       นายธนพัฒน์ ศรีชนะ          5              709
# 4773   YST_3_6        นายพิทยา พาลุสุข          6              763
# 4774   YST_3_7      นายศรายุทธ สุดสวาท          7              712
# 4775   YST_3_8    นางสาวสุนันทา สีชมภู          8              769
# 4776   YST_3_9        นายณัฐพล ศรีอุบล          9              726
#
#                                               image_url cons_id  mp_app_rank  \
# 0     https://cdn.ectreport.com/images/mp_candidates...   ACR_1            9
# ...

# %%
merged_df['party name'] = merged_df['party_id'].map(newmd1_4.set_index('id')['name'])
merged_df
# Out:
#      mp_app_id             mp_app_name  mp_app_no  mp_app_party_id  \
# 0      ACR_1_1   นางสาวปิยะมาศ บัวแก้ว          1              706
# 1     ACR_1_10  นางสุขสมรวย วันทนียกุล         10              709
# 2     ACR_1_11     นายการันต์ ลุนพันธ์         11              712
# 3     ACR_1_12          นายไสว ผลาวงศ์         12              742
# 4     ACR_1_13        นายสงบ โสภิพันธ์         13              761
# ...        ...                     ...        ...              ...
# 4772   YST_3_5       นายธนพัฒน์ ศรีชนะ          5              709
# 4773   YST_3_6        นายพิทยา พาลุสุข          6              763
# 4774   YST_3_7      นายศรายุทธ สุดสวาท          7              712
# 4775   YST_3_8    นางสาวสุนันทา สีชมภู          8              769
# 4776   YST_3_9        นายณัฐพล ศรีอุบล          9              726
#
#                                               image_url cons_id  mp_app_rank  \
# 0     https://cdn.ectreport.com/images/mp_candidates...   ACR_1            9
# ...

# %% [markdown]
# ## แบ่งตามเขต

# %%
Newmerged_df = merged_df[['mp_app_name','cons_id','mp_app_id','mp_app_party_id','party name','mp_app_vote']] #เลือกคอลลัมน์ที่ต้องการใช้ออกมา
Newmerged_df
# Out:
#                  mp_app_name cons_id mp_app_id  mp_app_party_id  \
# 0      นางสาวปิยะมาศ บัวแก้ว   ACR_1   ACR_1_1              706
# 1     นางสุขสมรวย วันทนียกุล   ACR_1  ACR_1_10              709
# 2        นายการันต์ ลุนพันธ์   ACR_1  ACR_1_11              712
# 3             นายไสว ผลาวงศ์   ACR_1  ACR_1_12              742
# 4           นายสงบ โสภิพันธ์   ACR_1  ACR_1_13              761
# ...                      ...     ...       ...              ...
# 4772       นายธนพัฒน์ ศรีชนะ   YST_3   YST_3_5              709
# 4773        นายพิทยา พาลุสุข   YST_3   YST_3_6              763
# 4774      นายศรายุทธ สุดสวาท   YST_3   YST_3_7              712
# 4775    นางสาวสุนันทา สีชมภู   YST_3   YST_3_8              769
# 4776        นายณัฐพล ศรีอุบล   YST_3   YST_3_9              726
#
#            party name  mp_app_vote
# 0       ชาติพัฒนากล้า          459
# 1           ภูมิใจไทย        38275
# 2     ประชาธิปไตยใหม่          126
# 3             คลองไทย          127
# ...

# %%
Newmerged_df = merged_df[['mp_app_name','cons_id','mp_app_id','mp_app_party_id','party name','mp_app_vote']] #ทำการเรียงผลโหวตที่ได้รับจากมากไปน้อยเพื่อโชว์ 10 อันดับแรกแบบแบ่งตามเขต
Newmerged_df
# Out:
#                  mp_app_name cons_id mp_app_id  mp_app_party_id  \
# 0      นางสาวปิยะมาศ บัวแก้ว   ACR_1   ACR_1_1              706
# 1     นางสุขสมรวย วันทนียกุล   ACR_1  ACR_1_10              709
# 2        นายการันต์ ลุนพันธ์   ACR_1  ACR_1_11              712
# 3             นายไสว ผลาวงศ์   ACR_1  ACR_1_12              742
# 4           นายสงบ โสภิพันธ์   ACR_1  ACR_1_13              761
# ...                      ...     ...       ...              ...
# 4772       นายธนพัฒน์ ศรีชนะ   YST_3   YST_3_5              709
# 4773        นายพิทยา พาลุสุข   YST_3   YST_3_6              763
# 4774      นายศรายุทธ สุดสวาท   YST_3   YST_3_7              712
# 4775    นางสาวสุนันทา สีชมภู   YST_3   YST_3_8              769
# 4776        นายณัฐพล ศรีอุบล   YST_3   YST_3_9              726
#
#            party name  mp_app_vote
# 0       ชาติพัฒนากล้า          459
# 1           ภูมิใจไทย        38275
# 2     ประชาธิปไตยใหม่          126
# 3             คลองไทย          127
# ...

# %%
top1_10 = Newmerged_df.sort_values(by='mp_app_vote', ascending=False).head(10) #ทำการเรียงผลโหวตที่ได้รับจากมากไปน้อยเพื่อโชว์ 10 อันดับแรกแบบแบ่งตามเขต
top1_10
# Out:
#                     mp_app_name cons_id mp_app_id  mp_app_party_id  \
# 4297             นายทวี สุระบาล   TRG_2   TRG_2_6              743
# 4354       นายสมศักดิ์ บุญประชม  UBN_10  UBN_10_1              773
# 960      นางสาวพุธิตา ชัยอนันต์   CMI_4   CMI_4_5              726
# 1075      นายเชิงชาย ชาลีรินทร์   CPM_2   CPM_2_6              705
# 3331      นางสาวจิราพร สินธุไพร   RET_5   RET_5_3              705
# 2168  นายอาทิตย์ หวังศุภกิจโกศล  NMA_11  NMA_11_4              705
# 3906          นางสาวนิตยา มีศรี   SPK_5   SPK_5_5              726
# 1739  นายวิทวิสิทธิ์ ปันสวนปลูก   LPN_1   LPN_1_3              726
# 1960          นายชลน่าน ศรีแก้ว   NAN_2   NAN_2_1              705
# 1577        นายวิรัช พิมพะนิตย์   KSN_1   KSN_1_9              705
#
#           party name  mp_app_vote
# 4297    พลังประชารัฐ        63185
# 4354  เพื่อไทรวมพลัง        63127
# 960          ก้าวไกล        62009
# 1075        เพื่อไทย        61414
# 3331        เพื่อไทย        61288
# ...

# %% [markdown]
# ## แบ่งตามพรรค

# %%
Newmerged_df2 = merged_df[['mp_app_name','party name','mp_app_party_id','party_list_vote']] #เลือกคอลลัมน์ที่ต้องการใช้ออกมา
Newmerged_df2
# Out:
#                  mp_app_name       party name  mp_app_party_id  \
# 0      นางสาวปิยะมาศ บัวแก้ว    ชาติพัฒนากล้า              706
# 1     นางสุขสมรวย วันทนียกุล        ภูมิใจไทย              709
# 2        นายการันต์ ลุนพันธ์  ประชาธิปไตยใหม่              712
# 3             นายไสว ผลาวงศ์          คลองไทย              742
# 4           นายสงบ โสภิพันธ์    พลังสังคมใหม่              761
# ...                      ...              ...              ...
# 4772       นายธนพัฒน์ ศรีชนะ        ภูมิใจไทย              709
# 4773        นายพิทยา พาลุสุข  รวมไทยสร้างชาติ              763
# 4774      นายศรายุทธ สุดสวาท  ประชาธิปไตยใหม่              712
# 4775    นางสาวสุนันทา สีชมภู         ไทยภักดี              769
# 4776        นายณัฐพล ศรีอุบล          ก้าวไกล              726
#
#       party_list_vote
# 0                 132
# 1                9761
# 2                 408
# 3                  36
# 4                 672
# ...               ...
# 4772             4466
# ...

# %%
top_10 = Newmerged_df2.sort_values(by='party_list_vote', ascending=False).head(10) #ทำการเรียงผลโหวตที่ได้รับจากมากไปน้อยเพื่อโชว์ 10 อันดับแรกแบบแบ่งตามพรรค
top_10
# Out:
#                     mp_app_name party name  mp_app_party_id  party_list_vote
# 3295            นายฉลาด ขามช่วง   เพื่อไทย              705            83851
# 2023        นายปรีติ เจริญศิลป์    ก้าวไกล              726            68952
# 3906          นางสาวนิตยา มีศรี    ก้าวไกล              726            66797
# 1739  นายวิทวิสิทธิ์ ปันสวนปลูก    ก้าวไกล              726            65196
# 3940       นายตรัยวรรธน์ อิ่มใจ    ก้าวไกล              726            60288
# 2048       นายเกียรติคุณ ต้นยาง    ก้าวไกล              726            60207
# 3573       นายณัฐพงษ์ สุมโนธรรม    ก้าวไกล              726            59147
# 3297        นายทินกร อ่อนประทุม    ก้าวไกล              726            58483
# 960      นางสาวพุธิตา ชัยอนันต์    ก้าวไกล              726            58461
# 3583       นายศิริโรจน์ ธนิกกุล    ก้าวไกล              726            58312

# %% [markdown]
# # 2.create a table that shows a list of ELECTED constituency candidate names and their parties. Sort the table by voted they received and showed only 5 worst perform (30 points)
# สร้างตารางที่แสดงรายการชื่อผู้สมัครรับเลือกตั้งแบบแบ่งเขตเลือกตั้งและพรรค จัดเรียงตารางตามการโหวตที่พวกเขาได้รับ และแสดงผลงานแย่ที่สุดเพียง 5 รายการ (30 คะแนน)

# %% [markdown]
# ## แบ่งตามเขต

# %%
top_5 = Newmerged_df.sort_values(by='mp_app_vote', ascending=True).head(5) #ทำการเรียงผลโหวตที่ได้รับจากน้อยไปมากเพื่อโชว์ผลงานแย่ที่สุดเพียง 5 รายการ
top_5
# Out:
#                     mp_app_name cons_id mp_app_id  mp_app_party_id  \
# 4411       นายพรหมมินทร์ ยืนสุข   UBN_4  UBN_4_12              712
# 3527          นายประวิทย์ คงราช   SKA_7   SKA_7_9              742
# 3392   นายอนุวิทย์ วงศ์วารินทร์   RYG_1  RYG_1_11              742
# 2060    สิบตำรวจโทสมชาย ศรีเย็น   NBI_8   NBI_8_8              727
# 998   นายกันต์พงษ์ วิเลิศศักดิ์   CMI_7  CMI_7_14              702
#
#            party name  mp_app_vote
# 4411  ประชาธิปไตยใหม่            0
# 3527          คลองไทย            0
# 3392          คลองไทย            0
# 2060     ทางเลือกใหม่            0
# 998        ประชากรไทย            0

# %% [markdown]
# ## แบ่งตามพรรค

# %%
top2_5 = Newmerged_df2.sort_values(by='party_list_vote', ascending=True).head(5) #ทำการเรียงผลโหวตที่ได้รับจากน้อยไปมากเพื่อโชว์ผลงานแย่ที่สุดเพียง 5 รายการ
top2_5
# Out:
#                   mp_app_name    party name  mp_app_party_id  party_list_vote
# 3116  นางวลัยพรรณ รัตนสมบูรณ์  พลังปวงชนไทย              737                0
# 2001    นายธีระพงษ์ แก้ววิเศษ     พลังสังคม              745                1
# 3046     นางสาวรมิดา หอกระโทก    แนวทางใหม่              770                2
# 3369       นายปรเมษฐ์ แสนกลาง  พลังปวงชนไทย              737                2
# 3545      นายมาวิน มากจังหวัด      ช่วยชาติ              725                3

# %% [markdown]
# # 3 create a table from the party list vote result that shows the ratio between the vote recieved by the highest party and the second highest party of each constituency area.
#
# สร้างตารางจากผลการลงคะแนนแบบบัญชีรายชื่อพรรคที่แสดงอัตราส่วนระหว่างคะแนนเสียงที่ได้รับจากพรรคสูงสุดกับพรรคสูงสุดอันดับสองของแต่ละพื้นที่เขตเลือกตั้ง

# %%
md3_1 = pd.read_csv('/info_party_overview.csv') #ข้อมูลทีแสดงรายชื่อพรรค
md3_1.head()
# Out:
#     id  party_no           name  abbr    color  \
# 0  701      26.0   ประชาธิปัตย์  ปชป.  #06aff3
# 1  702      63.0     ประชากรไทย  ปชท.  #0f41ce
# 2  703      60.0   ความหวังใหม่  ควม.  #e6b750
# 3  705      29.0       เพื่อไทย   พท.  #da3731
# 4  706      14.0  ชาติพัฒนากล้า  ชพก.  #233e8a
#
#                                             logo_url
# 0  https://cdn.ectreport.com/images/logos/ประชาธิ...
# 1  https://cdn.ectreport.com/images/logos/ประชากร...
# 2  https://cdn.ectreport.com/images/logos/ความหวั...
# 3  https://cdn.ectreport.com/images/logos/เพื่อไท...
# 4  https://cdn.ectreport.com/images/logos/ชาติพัฒ...

# %% [markdown]
# ## เช็ค missing value

# %%
md3_1.isnull().any() # ไม่มีค่า missing value
# Out:
# id          False
# party_no     True
# name        False
# abbr        False
# color       False
# logo_url    False
# dtype: bool

# %%
New_df3= merged_df[['mp_app_party_id','cons_id','party_list_vote']] #เลือกคอลลัมน์ที่ต้องการใช้ออกมา
New_df3
# Out:
#       mp_app_party_id cons_id  party_list_vote
# 0                 706   ACR_1              132
# 1                 709   ACR_1             9761
# 2                 712   ACR_1              408
# 3                 742   ACR_1               36
# 4                 761   ACR_1              672
# ...               ...     ...              ...
# 4772              709   YST_3             4466
# 4773              763   YST_3             3328
# 4774              712   YST_3              808
# 4775              769   YST_3              118
# 4776              726   YST_3            29942
#
# [4777 rows x 3 columns]

# %%
df_grouped  = New_df3.groupby('cons_id').apply(lambda x: x.sort_values('party_list_vote', ascending=False)) # กลุ่มตามพื้นที่เขตเลือกตั้งและเรียงลำดับคะแนนในกลุ่มนั้น

# %%
df_top2 = New_df3.groupby('cons_id').head(2) # ดึงข้อมูลพรรคที่ได้คะแนนสูงสุดและคะแนนสูงสุดอันดับสองในแต่ละกลุ่ม

# %%
df_top2['500'] = df_top2.groupby('cons_id')['party_list_vote'].apply(lambda x: x / x.sum()) # คำนวณอัตราส่วนระหว่างคะแนนสูงสุดและคะแนนสูงสุดอันดับสอง
# Out:
# <ipython-input-24-ac3f5f38e7ea>:1: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   df_top2['500'] = df_top2.groupby('cons_id')['party_list_vote'].apply(lambda x: x / x.sum()) # คำนวณอัตราส่วนระหว่างคะแนนสูงสุดและคะแนนสูงสุดอันดับสอง
# <ipython-input-24-ac3f5f38e7ea>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df_top2 = df_top2.drop(columns=['cons_id', 'party_list_vote']) # ลบข้อมูลที่ไม่ต้องการ

# %%
df_top2 # แสดงผลลัพธ์
# Out:
#       mp_app_party_id       500
# 0                 706  0.013343
# 1                 709  0.986657
# 13                726  0.811610
# 14                709  0.188390
# 25                726  0.975084
# ...               ...       ...
# 4741              739  0.003786
# 4753              743  0.693252
# 4754              769  0.306748
# 4766              701  0.327933
# 4767              707  0.672067
#
# [800 rows x 2 columns]
